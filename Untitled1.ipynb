# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenpranavy/Special_pro/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/train_data.csv')
df
# Out:
#                                                    name   brand  \
# 0     All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Amazon
# 1           Amazon - Echo Plus w/ Built-In Hub - Silver  Amazon
# 2     Amazon Echo Show Alexa-enabled Bluetooth Speak...  Amazon
# 3     Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...  Amazon
# 4     Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Amazon
# ...                                                 ...     ...
# 3995        Amazon - Echo Plus w/ Built-In Hub - Silver  Amazon
# 3996  Amazon Kindle E-Reader 6" Wifi (8th Generation...  Amazon
# 3997  Amazon Tap - Alexa-Enabled Portable Bluetooth ...  Amazon
# 3998  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Amazon
# 3999  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Amazon
#
#                                              categories  \
# 0     Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1     Amazon Echo,Smart Home,Networking,Home & Tools...
# 2     Amazon Echo,Virtual Assistant Speakers,Electro...
# 3     eBook Readers,Fire Tablets,Electronics Feature...
# 4     Computers/Tablets & Networking,Tablets & eBook...
# ...                                                 ...
# 3995  Amazon Echo,Smart Home,Networking,Home & Tools...
# 3996  Computers,Electronics Features,Tablets,Electro...
# 3997  Amazon Echo,Home Theater & Audio,MP3 MP4 Playe...
# 3998  Computers/Tablets & Networking,Tablets & eBook...
# 3999  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                 primaryCategories              reviews.date  \
# 0                     Electronics  2016-12-26T00:00:00.000Z
# 1            Electronics,Hardware  2018-01-17T00:00:00.000Z
# 2            Electronics,Hardware  2017-12-20T00:00:00.000Z
# 3     Office Supplies,Electronics  2017-08-04T00:00:00.000Z
# 4                     Electronics  2017-01-23T00:00:00.000Z
# ...                           ...                       ...
# 3995         Electronics,Hardware  2017-12-08T00:00:00.000Z
# 3996                  Electronics  2017-03-31T00:00:00.000Z
# 3997                  Electronics  2017-01-19T00:00:00.000Z
# 3998                  Electronics  2016-05-27T00:00:00.000Z
# 3999                  Electronics  2016-12-30T00:00:00.000Z
#
#                                            reviews.text  \
# 0     Purchased on Black FridayPros - Great Price (e...
# 1     I purchased two Amazon in Echo Plus and two do...
# 2     Just an average Alexa option. Does show a few ...
# 3     very good product. Exactly what I wanted, and ...
# 4     This is the 3rd one I've purchased. I've bough...
# ...                                                 ...
# 3995  It‚Äôs fun for the family to play with, but it...
# 3996  I love the Kindle, it is a great product. It r...
# 3997  I was looking for a blutooth speaker to use wi...
# 3998  This is the second Amazon Fire 7 tablet I have...
# 3999  very satisfied with tablet, very fast and effi...
#
#                                reviews.title sentiment
# 0                            Powerful tablet  Positive
# 1                   Amazon Echo Plus AWESOME  Positive
# 2                                    Average   Neutral
# 3                                Greattttttt  Positive
# 4                              Very durable!  Positive
# ...                                      ...       ...
# 3995                                 Fun toy  Positive
# 3996                           Great Product  Positive
# 3997                    Great "dumb" speaker  Positive
# 3998  A great 7 inch tablet at a great price  Positive
# 3999                       Gets the job done  Positive
#
# [4000 rows x 8 columns]

# %%
# Display the first few rows of the DataFrame 'df' to inspect the data.
df.head()
# Out:
#                                                 name   brand  \
# 0  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Amazon
# 1        Amazon - Echo Plus w/ Built-In Hub - Silver  Amazon
# 2  Amazon Echo Show Alexa-enabled Bluetooth Speak...  Amazon
# 3  Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...  Amazon
# 4  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Amazon
#
#                                           categories  \
# 0  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  Amazon Echo,Smart Home,Networking,Home & Tools...
# 2  Amazon Echo,Virtual Assistant Speakers,Electro...
# 3  eBook Readers,Fire Tablets,Electronics Feature...
# 4  Computers/Tablets & Networking,Tablets & eBook...
#
#              primaryCategories              reviews.date  \
# 0                  Electronics  2016-12-26T00:00:00.000Z
# 1         Electronics,Hardware  2018-01-17T00:00:00.000Z
# 2         Electronics,Hardware  2017-12-20T00:00:00.000Z
# 3  Office Supplies,Electronics  2017-08-04T00:00:00.000Z
# 4                  Electronics  2017-01-23T00:00:00.000Z
#
#                                         reviews.text  \
# 0  Purchased on Black FridayPros - Great Price (e...
# 1  I purchased two Amazon in Echo Plus and two do...
# 2  Just an average Alexa option. Does show a few ...
# 3  very good product. Exactly what I wanted, and ...
# 4  This is the 3rd one I've purchased. I've bough...
#
#               reviews.title sentiment
# 0           Powerful tablet  Positive
# 1  Amazon Echo Plus AWESOME  Positive
# 2                   Average   Neutral
# 3               Greattttttt  Positive
# 4             Very durable!  Positive

# %%
# Display the last few rows of the DataFrame 'df' to examine the end of the data.
df.tail()
# Out:
#                                                    name   brand  \
# 3995        Amazon - Echo Plus w/ Built-In Hub - Silver  Amazon
# 3996  Amazon Kindle E-Reader 6" Wifi (8th Generation...  Amazon
# 3997  Amazon Tap - Alexa-Enabled Portable Bluetooth ...  Amazon
# 3998  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Amazon
# 3999  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Amazon
#
#                                              categories     primaryCategories  \
# 3995  Amazon Echo,Smart Home,Networking,Home & Tools...  Electronics,Hardware
# 3996  Computers,Electronics Features,Tablets,Electro...           Electronics
# 3997  Amazon Echo,Home Theater & Audio,MP3 MP4 Playe...           Electronics
# 3998  Computers/Tablets & Networking,Tablets & eBook...           Electronics
# 3999  Electronics,iPad & Tablets,All Tablets,Fire Ta...           Electronics
#
#                   reviews.date  \
# 3995  2017-12-08T00:00:00.000Z
# 3996  2017-03-31T00:00:00.000Z
# 3997  2017-01-19T00:00:00.000Z
# 3998  2016-05-27T00:00:00.000Z
# 3999  2016-12-30T00:00:00.000Z
#
#                                            reviews.text  \
# 3995  It‚Äôs fun for the family to play with, but it...
# 3996  I love the Kindle, it is a great product. It r...
# 3997  I was looking for a blutooth speaker to use wi...
# 3998  This is the second Amazon Fire 7 tablet I have...
# 3999  very satisfied with tablet, very fast and effi...
#
#                                reviews.title sentiment
# 3995                                 Fun toy  Positive
# 3996                           Great Product  Positive
# 3997                    Great "dumb" speaker  Positive
# 3998  A great 7 inch tablet at a great price  Positive
# 3999                       Gets the job done  Positive

# %%
# Get the shape of the DataFrame 'df' to determine the number of rows and columns.
df.shape
# Out:
# (4000, 8)

# %%
# Get the column names of the DataFrame 'df' to see the names of the data columns.
df.columns
# Out:
# Index(['name', 'brand', 'categories', 'primaryCategories', 'reviews.date',
#        'reviews.text', 'reviews.title', 'sentiment'],
#       dtype='object')

# %%
# Count the number of duplicated rows in the DataFrame 'df' and sum them up.
df.duplicated().sum()
# Out:
# 58

# %%
# Count the number of missing (null) values in each column of the DataFrame 'df' and sum them up.
df.isnull().sum()
# Out:
# name                  0
# brand                 0
# categories            0
# primaryCategories     0
# reviews.date          0
# reviews.text          0
# reviews.title        10
# sentiment             0
# dtype: int64

# %%
# Display information about the DataFrame 'df,' including data types and non-null counts.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               4000 non-null   object
#  1   brand              4000 non-null   object
#  2   categories         4000 non-null   object
#  3   primaryCategories  4000 non-null   object
#  4   reviews.date       4000 non-null   object
#  5   reviews.text       4000 non-null   object
#  6   reviews.title      3990 non-null   object
#  7   sentiment          4000 non-null   object
# dtypes: object(8)
# memory usage: 250.1+ KB

# %%
  # Import the Matplotlib library to create data visualizations and plots.
import matplotlib.pyplot as plt

# Import the Seaborn library for statistical data visualization.
import seaborn as sns

# %%
# Import the 'warnings' module and set it to ignore warnings.

import warnings
warnings.filterwarnings('ignore')

# %%
# Create a copy of the DataFrame 'df' and store it in a new DataFrame 'df_new'.
df_new = df.copy()

# %%
# Define a text cleaning function that converts text to lowercase and removes leading/trailing whitespace.

def clean_text(text):
 # Convert text to lowercase.
 text = text.lower()

 # Remove leading and trailing whitespace.
 return text.strip()

# %%
df_new.rename(columns={"reviews.text": "reviewstext"}, inplace=True)

# %%
# Apply the 'clean_text' function to preprocess the 'Reviews' column and store it in a new column 'message'.

df_new['message'] = df_new['reviewstext'].apply(lambda x: clean_text(x))

# %%
# Import the 'string' module and retrieve a set of punctuation characters.

import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Define a function to remove punctuation from text and apply it to the 'Reviews' column.

def remove_punctuation(text):
  # Join characters that are not in the set of punctuation characters.
  punctuationfree="".join([i for i in text if i not in string.punctuation])
  return punctuationfree

# Apply the 'remove_punctuation' function to the 'Reviews' column.
df_new['reviewstext']= df_new['reviewstext'].apply(lambda x:remove_punctuation(x))

# %%
df_new.head()
# Out:
#                                                 name   brand  \
# 0  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Amazon
# 1        Amazon - Echo Plus w/ Built-In Hub - Silver  Amazon
# 2  Amazon Echo Show Alexa-enabled Bluetooth Speak...  Amazon
# 3  Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...  Amazon
# 4  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Amazon
#
#                                           categories  \
# 0  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  Amazon Echo,Smart Home,Networking,Home & Tools...
# 2  Amazon Echo,Virtual Assistant Speakers,Electro...
# 3  eBook Readers,Fire Tablets,Electronics Feature...
# 4  Computers/Tablets & Networking,Tablets & eBook...
#
#              primaryCategories              reviews.date  \
# 0                  Electronics  2016-12-26T00:00:00.000Z
# 1         Electronics,Hardware  2018-01-17T00:00:00.000Z
# 2         Electronics,Hardware  2017-12-20T00:00:00.000Z
# 3  Office Supplies,Electronics  2017-08-04T00:00:00.000Z
# 4                  Electronics  2017-01-23T00:00:00.000Z
#
#                                          reviewstext  \
# 0  Purchased on Black FridayPros  Great Price eve...
# 1  I purchased two Amazon in Echo Plus and two do...
# 2  Just an average Alexa option Does show a few t...
# 3  very good product Exactly what I wanted and a ...
# 4  This is the 3rd one Ive purchased Ive bought o...
#
#               reviews.title sentiment  \
# 0           Powerful tablet  Positive
# 1  Amazon Echo Plus AWESOME  Positive
# 2                   Average   Neutral
# 3               Greattttttt  Positive
# 4             Very durable!  Positive
#
#                                              message
# 0  purchased on black fridaypros - great price (e...
# 1  i purchased two amazon in echo plus and two do...
# 2  just an average alexa option. does show a few ...
# 3  very good product. exactly what i wanted, and ...
# 4  this is the 3rd one i've purchased. i've bough...

# %%
# Define a tokenization function using regular expressions and apply it to the 'Reviews' column.
import re

def tokenization(text):
  # Split the text into tokens using regular expression pattern 'W+'.
  tokens = re.split('W+',text)
  return tokens

# Apply the 'tokenization' function to the 'Reviews' column.
df_new['reviewstext']= df_new['reviewstext'].apply(lambda x: tokenization(x))

# %%
df_new['reviewstext']
# Out:
# 0       [Purchased on Black FridayPros  Great Price ev...
# 1       [I purchased two Amazon in Echo Plus and two d...
# 2       [Just an average Alexa option Does show a few ...
# 3       [very good product Exactly what I wanted and a...
# 4       [This is the 3rd one Ive purchased Ive bought ...
#                               ...
# 3995    [It‚Äôs fun for the family to play with but it...
# 3996    [I love the Kindle it is a great product It re...
# 3997    [I was looking for a blutooth speaker to use w...
# 3998    [This is the second Amazon Fire 7 tablet I hav...
# 3999    [very satisfied with tablet very fast and effi...
# Name: reviewstext, Length: 4000, dtype: object

# %%
# Download the NLTK stopwords dataset for English.

import nltk
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Remove stopwords from each review
def remove_stopwords(text):
 output= " ".join(i for i in text if i not in stopwords)
 return output

# %%
df_new['reviewstext']= df_new['reviewstext'].apply(lambda x:remove_stopwords(x))

# %%
df_new.head()
# Out:
#                                                 name   brand  \
# 0  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Amazon
# 1        Amazon - Echo Plus w/ Built-In Hub - Silver  Amazon
# 2  Amazon Echo Show Alexa-enabled Bluetooth Speak...  Amazon
# 3  Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...  Amazon
# 4  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Amazon
#
#                                           categories  \
# 0  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  Amazon Echo,Smart Home,Networking,Home & Tools...
# 2  Amazon Echo,Virtual Assistant Speakers,Electro...
# 3  eBook Readers,Fire Tablets,Electronics Feature...
# 4  Computers/Tablets & Networking,Tablets & eBook...
#
#              primaryCategories              reviews.date  \
# 0                  Electronics  2016-12-26T00:00:00.000Z
# 1         Electronics,Hardware  2018-01-17T00:00:00.000Z
# 2         Electronics,Hardware  2017-12-20T00:00:00.000Z
# 3  Office Supplies,Electronics  2017-08-04T00:00:00.000Z
# 4                  Electronics  2017-01-23T00:00:00.000Z
#
#                                          reviewstext  \
# 0  Purchased on Black FridayPros  Great Price eve...
# 1  I purchased two Amazon in Echo Plus and two do...
# 2  Just an average Alexa option Does show a few t...
# 3  very good product Exactly what I wanted and a ...
# 4  This is the 3rd one Ive purchased Ive bought o...
#
#               reviews.title sentiment  \
# 0           Powerful tablet  Positive
# 1  Amazon Echo Plus AWESOME  Positive
# 2                   Average   Neutral
# 3               Greattttttt  Positive
# 4             Very durable!  Positive
#
#                                              message
# 0  purchased on black fridaypros - great price (e...
# 1  i purchased two amazon in echo plus and two do...
# 2  just an average alexa option. does show a few ...
# 3  very good product. exactly what i wanted, and ...
# 4  this is the 3rd one i've purchased. i've bough...

# %%
# Perform word stemming using Porter Stemmer
from nltk.stem.porter import PorterStemmer
porter_stemmer = PorterStemmer()

# %%
def stemming(text):
 stem_text = "".join([porter_stemmer.stem(word) for word in text])
 return stem_text
df_new['reviewstext']=df_new['reviewstext'].apply(lambda x: stemming(x))

# %%
# Perform word lemmatization using WordNet Lemmatizer
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
def lemmatizer(text):
 lemm_text = "".join([wordnet_lemmatizer.lemmatize(word) for word in text])
 return lemm_text
df_new ['reviewstext']=df_new['reviewstext'].apply(lambda x:lemmatizer(x))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Clean text by removing square brackets and words containing numbers
def clean_text(text):
 text = re.sub('\[.*\]','', text).strip() # Remove text in square brackets
 text = re.sub('\S*\d\S*\s*','', text).strip() # Remove words containing numbers
 return text.strip()

# %%
df_new['reviewstext'] = df_new.reviewstext.apply(lambda x: clean_text(x))

# %%
# Download and load spaCy model for English language
import spacy
spacy.cli.download("en_core_web_sm")
nlp = spacy.load("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Define a lemmatizer function using spaCy
stopwords = nlp.Defaults.stop_words
def lemmatizer(text):
 doc = nlp(text)
 sent = [token.lemma_ for token in doc if not token.text in set(stopwords)]
 return ' '.join(sent)

# %%
df_new['reviewstext'] = df_new.reviewstext.apply(lambda x: lemmatizer(x))

# %%
df_new.head()
# Out:
#                                                 name   brand  \
# 0  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Amazon
# 1        Amazon - Echo Plus w/ Built-In Hub - Silver  Amazon
# 2  Amazon Echo Show Alexa-enabled Bluetooth Speak...  Amazon
# 3  Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...  Amazon
# 4  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Amazon
#
#                                           categories  \
# 0  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  Amazon Echo,Smart Home,Networking,Home & Tools...
# 2  Amazon Echo,Virtual Assistant Speakers,Electro...
# 3  eBook Readers,Fire Tablets,Electronics Feature...
# 4  Computers/Tablets & Networking,Tablets & eBook...
#
#              primaryCategories              reviews.date  \
# 0                  Electronics  2016-12-26T00:00:00.000Z
# 1         Electronics,Hardware  2018-01-17T00:00:00.000Z
# 2         Electronics,Hardware  2017-12-20T00:00:00.000Z
# 3  Office Supplies,Electronics  2017-08-04T00:00:00.000Z
# 4                  Electronics  2017-01-23T00:00:00.000Z
#
#                                          reviewstext  \
# 0  purchase black fridaypro   great price salever...
# 1  purchase amazon echo plus dot plus fire stick ...
# 2          average alexa option thing screen limited
# 3               good product exactly want good price
# 4  ve purchase ve buy niece case compare hold pro...
#
#               reviews.title sentiment  \
# 0           Powerful tablet  Positive
# 1  Amazon Echo Plus AWESOME  Positive
# 2                   Average   Neutral
# 3               Greattttttt  Positive
# 4             Very durable!  Positive
#
#                                              message
# 0  purchased on black fridaypros - great price (e...
# 1  i purchased two amazon in echo plus and two do...
# 2  just an average alexa option. does show a few ...
# 3  very good product. exactly what i wanted, and ...
# 4  this is the 3rd one i've purchased. i've bough...

# %%
# Remove URLs from the text
def remove_urls(vTEXT):
 vTEXT = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', vTEXT, flags=re.MULTILINE)
 return(vTEXT)

# %%
df_new['reviewstext'] = df_new.reviewstext.apply(lambda x: remove_urls(x))

# %%
# Remove digits from the text
def remove_digits(text):
 clean_text = re.sub(r"\b[0-9]+\b\s*", "", text)
 return(text)

# %%
df_new['reviewstext'] = df_new.reviewstext.apply(lambda x: remove_digits(x))

# %%
# Remove digits from individual words in the text
def remove_digits1(sample_text):
 clean_text = " ".join([w for w in sample_text.split() if not w.isdigit()]) # Side effect: remo
 return(clean_text)

# %%
df_new['reviewstext'] = df_new.reviewstext.apply(lambda x: remove_digits1(x))

# %%
def remove_emojis(data):
 emoji_pattern = re.compile("["
 u"\U0001F600-\U0001F64F" # emoticons
u"\U0001F300-\U0001F5FF" # symbols & pictographs
u"\U0001F680-\U0001F6FF" # transport & map symbols
u"\U0001F1E0-\U0001F1FF" # flags (iOS)
"]+", flags=re.UNICODE)
 return re.sub(emoji_pattern, '', data)

# %%
df_new['reviewstext'] = df_new.reviewstext.apply(lambda x: remove_emojis(x))

# %%
df_new
# Out:
#                                                    name   brand  \
# 0     All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Amazon
# 1           Amazon - Echo Plus w/ Built-In Hub - Silver  Amazon
# 2     Amazon Echo Show Alexa-enabled Bluetooth Speak...  Amazon
# 3     Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...  Amazon
# 4     Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Amazon
# ...                                                 ...     ...
# 3995        Amazon - Echo Plus w/ Built-In Hub - Silver  Amazon
# 3996  Amazon Kindle E-Reader 6" Wifi (8th Generation...  Amazon
# 3997  Amazon Tap - Alexa-Enabled Portable Bluetooth ...  Amazon
# 3998  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...  Amazon
# 3999  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...  Amazon
#
#                                              categories  \
# 0     Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1     Amazon Echo,Smart Home,Networking,Home & Tools...
# 2     Amazon Echo,Virtual Assistant Speakers,Electro...
# 3     eBook Readers,Fire Tablets,Electronics Feature...
# 4     Computers/Tablets & Networking,Tablets & eBook...
# ...                                                 ...
# 3995  Amazon Echo,Smart Home,Networking,Home & Tools...
# 3996  Computers,Electronics Features,Tablets,Electro...
# 3997  Amazon Echo,Home Theater & Audio,MP3 MP4 Playe...
# 3998  Computers/Tablets & Networking,Tablets & eBook...
# 3999  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                 primaryCategories              reviews.date  \
# 0                     Electronics  2016-12-26T00:00:00.000Z
# 1            Electronics,Hardware  2018-01-17T00:00:00.000Z
# 2            Electronics,Hardware  2017-12-20T00:00:00.000Z
# 3     Office Supplies,Electronics  2017-08-04T00:00:00.000Z
# 4                     Electronics  2017-01-23T00:00:00.000Z
# ...                           ...                       ...
# 3995         Electronics,Hardware  2017-12-08T00:00:00.000Z
# 3996                  Electronics  2017-03-31T00:00:00.000Z
# 3997                  Electronics  2017-01-19T00:00:00.000Z
# 3998                  Electronics  2016-05-27T00:00:00.000Z
# 3999                  Electronics  2016-12-30T00:00:00.000Z
#
#                                             reviewstext  \
# 0     purchased on black fridaypros great price even...
# 1     i purchased two amazon in echo plus and two do...
# 2     just an average alexa option does show a few t...
# 3     very good product exactly what i wanted and a ...
# 4     this is the one ive purchased ive bought one f...
# ...                                                 ...
# 3995  it‚äôs fun for the family to play with but it ...
# 3996  i love the kindle it is a great product it red...
# 3997  i was looking for a blutooth speaker to use wi...
# 3998  this is the second amazon fire tablet i have p...
# 3999  very satisfied with tablet very fast and effic...
#
#                                reviews.title sentiment  \
# 0                            Powerful tablet  Positive
# 1                   Amazon Echo Plus AWESOME  Positive
# 2                                    Average   Neutral
# 3                                Greattttttt  Positive
# 4                              Very durable!  Positive
# ...                                      ...       ...
# 3995                                 Fun toy  Positive
# 3996                           Great Product  Positive
# 3997                    Great "dumb" speaker  Positive
# 3998  A great 7 inch tablet at a great price  Positive
# 3999                       Gets the job done  Positive
#
#                                                 message
# 0     purchased on black fridaypros - great price (e...
# 1     i purchased two amazon in echo plus and two do...
# 2     just an average alexa option. does show a few ...
# 3     very good product. exactly what i wanted, and ...
# 4     this is the 3rd one i've purchased. i've bough...
# ...                                                 ...
# 3995  it‚äôs fun for the family to play with, but it...
# 3996  i love the kindle, it is a great product. it r...
# 3997  i was looking for a blutooth speaker to use wi...
# 3998  this is the second amazon fire 7 tablet i have...
# 3999  very satisfied with tablet, very fast and effi...
#
# [4000 rows x 9 columns]
